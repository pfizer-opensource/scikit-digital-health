# %%
# %matplotlib widget

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import sys
import h5py
from scipy import signal
from sklearn.decomposition import PCA
from PfyMU.gait.train_classifier.core import load_datasets_v2

# %%
steps = {
    'walking': 0.15,
    'default': 90
}

# %%
# gait_sets_path = Path('/Users/adamol/Documents/Datasets/gait/processed')
gait_sets_path = Path('/Users/ladmin/Desktop/gait_dataset_cleaning/processed/')

datasets = [
    gait_sets_path / 'basa',
    gait_sets_path / 'daliac',
    gait_sets_path / 'fallalld',
]

fs = 20.0

X, Y, subjects, activities = load_datasets_v2(
    datasets,
    device_location = 'Wrist',
    goal_fs=fs, 
    acc_mag=False, 
    window_length=3.0, 
    window_step=steps
)
# Out:
# processing dataset /Users/ladmin/Desktop/gait_dataset_cleaning/processed/basa
# processing dataset /Users/ladmin/Desktop/gait_dataset_cleaning/processed/daliac
# processing dataset /Users/ladmin/Desktop/gait_dataset_cleaning/processed/fallalld

# %% [markdown]
# ## Dataset class summary

# %%
print('Total samples (3.0s windows): ', Y.size)
print('Total walking samples: ', (Y==1).sum())
print('Total non-walking samples: ', Y.size - (Y==1).sum(), '\n')
print(f'% walking samples: {(Y==1).sum() / Y.size * 100:.2f}')
# Out:
# Total samples (3.0s windows):  83398
# Total walking samples:  40390
# Total non-walking samples:  43008
#
# % walking samples: 48.43

# %%
unq_act, act_ct = np.unique(activities, return_counts=True)
N = np.sum(act_ct)
si = np.argsort(act_ct)
for a, c in zip(unq_act[si], act_ct[si]):
    print(f'{a:30s}: {c:5d} / {N:5d}{c/N:8.2f}')
# Out:
# standing-faint-backward-norota:    28 / 83398    0.00
# sitting-faint-backward-norotat:    28 / 83398    0.00
# sitting-faint-forward-norotati:    32 / 83398    0.00
# standing-faint-forward-norotat:    32 / 83398    0.00
# standing-faint-vertical-norota:    44 / 83398    0.00
# standing-faint-lateral-norotat:    56 / 83398    0.00
# walking-faint-backward-norotat:    60 / 83398    0.00
# sitting-faint-lateral-norotati:    64 / 83398    0.00
# walking-faint-lateral-norotati:    64 / 83398    0.00
# walking-faint-forward-norotati:    64 / 83398    0.00
# sit-lie-lose-balance-backward-:    64 / 83398    0.00
# sit-lie-lose-balance-forward-n:    68 / 83398    0.00
# fast-descending-stairs        :    92 / 83398    0.00
# start-descending-stairs       :   100 / 83398    0.00
# stop-descending-elevator      :   100 / 83398    0.00
# sit-lie-lose-balance-lateral-n:   100 / 83398    0.00
# single-raise-and-lower-hand   :   100 / 83398    0.00
# stop-descending-stairs        :   100 / 83398    0.00
# stop-ascending-stairs         :   100 / 83398    0.00
# start-ascending-elevator      :   100 / 83398    0.00
# stop-ascending-elevator       :   100 / 83398    0.00
# start-descending-elevator     :   100 / 83398    0.00
# start-ascending-stairs        :   100 / 83398    0.00
# fast-ascending-stairs         :   100 / 83398    0.00
# sitting-bus                   :   116 / 83398    0.00
# walking-slip-forward-norotatio:   120 / 83398    0.00
# fast-jogging                  :   120 / 83398    0.00
# stop-jogging                  :   124 / 83398    0.00
# start-jogging                 :   124 / 83398    0.00
# walking-slip-backward-rotation:   124 / 83398    0.00
# jogging-slip-forward-rotation-:   128 / 83398    0.00
# slow-jogging                  :   128 / 83398    0.00
# walking-slip-forward-rotation-:   132 / 83398    0.00
# jogging-stumble-forward-norota:   132 / 83398    0.00
# standing-bus                  :   136 / 83398    0.00
# fast-walking                  :   136 / 83398    0.00
# fail-to-stand                 :   140 / 83398    0.00
# stumble-walking               :   140 / 83398    0.00
# walking-stumble-forward-norota:   144 / 83398    0.00
# jogging-slip-forward-norotatio:   144 / 83398    0.00
# rope-jumping                  :   145 / 83398    0.00
# bending-down                  :   180 / 83398    0.00
# strong-jumping                :   184 / 83398    0.00
# light-jumping                 :   184 / 83398    0.00
# lowering-hand                 :   196 / 83398    0.00
# hand-beating-table            :   196 / 83398    0.00
# stop-waving                   :   200 / 83398    0.00
# stop-clapping                 :   200 / 83398    0.00
# start-waving                  :   200 / 83398    0.00
# waving                        :   200 / 83398    0.00
# start-clapping                :   200 / 83398    0.00
# raising-hand                  :   200 / 83398    0.00
# single-clap                   :   200 / 83398    0.00
# hand-shake                    :   200 / 83398    0.00
# clapping                      :   200 / 83398    0.00
# lying-turn-lateral-norotation-:   224 / 83398    0.00
# walking-slip-backward-norotati:   240 / 83398    0.00
# vacuuming                     :   250 / 83398    0.00
# start-walking                 :   264 / 83398    0.00
# stop-walking                  :   272 / 83398    0.00
# moderate-walking              :   276 / 83398    0.00
# rising-from-bed               :   280 / 83398    0.00
# turn-in-bed                   :   280 / 83398    0.00
# sweeping                      :   410 / 83398    0.00
# treadmill-running             :   507 / 83398    0.01
# cycling-50W                   :   512 / 83398    0.01
# cycling-100W                  :   513 / 83398    0.01
# washing-dishes                :   522 / 83398    0.01
# unconfirmed1                  :  1020 / 83398    0.01
# unconfirmed2                  :  1530 / 83398    0.02
# jogging                       :  3735 / 83398    0.04
# lying                         :  3783 / 83398    0.05
# sitting                       :  3943 / 83398    0.05
# standing                      :  4122 / 83398    0.05
# descending-stairs             :  4826 / 83398    0.06
# ascending-stairs              :  9142 / 83398    0.11
# walking                       : 39978 / 83398    0.48

# %% [markdown]
# ## Preprocessing

# %%
X.shape
# Out:
# (83398, 60, 3)

# %%
# High Pass Filter signal
cutoff, order = 0.25, 1
critical_frequency = [cutoff * 2.0 / fs]
[b, a] = signal.butter(N=order, Wn=critical_frequency, btype="highpass", analog=False)
X_filt = signal.filtfilt(b, a, X, padlen=10, axis=0)
X_filt.shape
# Out:
# (83398, 60, 3)

# %%
# PCA
pca = PCA(n_components=3)
X_pca = np.array([pca.fit_transform(X_filt[i])for i in range(len(X_filt))])
X_pca.shape
# Out:
# (83398, 60, 3)

# %% [markdown]
# ## Feature Generation

# %%
from PfyMU.features import *

# %%
FB = Bank(window_length=None, window_step=None)

# add features
FB + Mean()
FB + MeanCrossRate()
FB + StdDev()
FB + Skewness()
FB + Kurtosis()
FB + Range()
FB + IQR()
FB + RMS()
FB + Autocorrelation(lag=1, normalize=True)
FB + LinearSlope()
FB + SignalEntropy()
FB + SampleEntropy(m=4, r=1.0)
FB + PermutationEntropy(order=3, delay=1, normalize=True)
FB + ComplexityInvariantDistance(normalize=True)
FB + RangeCountPercentage(range_min=0, range_max=1.0)
FB + RatioBeyondRSigma(r=2.0)
FB + JerkMetric(normalize=True)
FB + DimensionlessJerk(log=True, signal_type='acceleration')
FB + SPARC()
FB + DominantFrequency(low_cutoff=0.25, high_cutoff=5.0)
FB + DominantFrequencyValue(low_cutoff=0.25, high_cutoff=5.0)
FB + PowerSpectralSum(low_cutoff=0.25, high_cutoff=5.0)
FB + SpectralFlatness(low_cutoff=0.25, high_cutoff=5.0)
FB + SpectralEntropy(low_cutoff=0.25, high_cutoff=5.0)
FB + DetailPower(wavelet='coif4', freq_band=[1.0, 3.0])
FB + DetailPowerRatio(wavelet='coif4', freq_band=[1.0, 3.0])

# %%
X_feat = FB.compute(X_pca, fs=20.0, windowed=True)
X_feat_pc1 = FB.compute(X_pca[:,:,0], fs=20.0, windowed=True)
X_feat_pc2 = FB.compute(X_pca[:,:,1], fs=20.0, windowed=True)
X_feat_pc3 = FB.compute(X_pca[:,:,2], fs=20.0, windowed=True)

# %% [markdown]
# ## Feature Exploration

# %%
print(X_feat[0])
feats = pd.DataFrame(
    index=range(X_feat.shape[0]), 
#     columns=['Subject', 'Activity', 'Label'] + [i.parent._name for i in FB._feat_list],
    columns=['Label'] + [i.parent._name for i in FB._feat_list],
    dtype='float'
)
# feats['Subject'] = feats.Subject.astype('str')
# feats['Activity'] = feats.Activity.astype('str')
feats.iloc[:, 1:] = X_feat
feats['Label'] = Y
# feats['Label'] = feats.Label.astype('int')
# # feats['Subject'] = subjects
# # feats['Activity'] = activities

# feat_names = [i.parent._name for i in FB._feat_list]
# Out:
# [ 5.08852220e-18 -4.04768811e-19  5.34873072e-19  1.83333333e-01
#   2.00000000e-01  3.66666667e-01  8.28652879e-02  3.13051750e-02
#   1.67615280e-02]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-475394e229f6> in <module>
#       8 # feats['Subject'] = feats.Subject.astype('str')
#       9 # feats['Activity'] = feats.Activity.astype('str')
# ---> 10 feats.iloc[:, 1:] = X_feat
#      11 feats['Label'] = Y
#      12 # feats['Label'] = feats.Label.astype('int')
#
# ~/.conda/envs/gait_dataset_cleaning/lib/python3.7/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     669             key = com.apply_if_callable(key, self.obj)
#     670         indexer = self._get_setitem_indexer(key)
# --> 671         self._setitem_with_indexer(indexer, value)
#     672
#     673     def _validate_key(self, key, axis: int):
#
# ~/.conda/envs/gait_dataset_cleaning/lib/python3.7/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1063             # actually do the set
#    1064             self.obj._consolidate_inplace()
# -> 1065             self.obj._data = self.obj._data.setitem(indexer=indexer, value=value)
#    1066             self.obj._maybe_update_cacher(clear=True)
#    1067
#
# ~/.conda/envs/gait_dataset_cleaning/lib/python3.7/site-packages/pandas/core/internals/managers.py in setitem(self, **kwargs)
#     559
#     560     def setitem(self, **kwargs):
# --> 561         return self.apply("setitem", **kwargs)
#     562
#     563     def putmask(self, **kwargs):
#
# ~/.conda/envs/gait_dataset_cleaning/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, filter, **kwargs)
#     440                 applied = b.apply(f, **kwargs)
#     441             else:
# --> 442                 applied = getattr(b, f)(**kwargs)
#     443             result_blocks = _extend_blocks(applied, result_blocks)
#     444
#
# ~/.conda/envs/gait_dataset_cleaning/lib/python3.7/site-packages/pandas/core/internals/blocks.py in setitem(self, indexer, value)
#     918         # set
#     919         else:
# --> 920             values[indexer] = value
#     921
#     922         if transpose:
#
# ValueError: could not broadcast input array from shape (83398,9) into shape (83398,3)

# %%
# feats.to_hdf('features.h5', key='no_preprocessing')

# %% [markdown]
# ### Feature distributions

# %%
plt.close('all')

f, ax = plt.subplots(nrows=7, ncols=4, figsize=(10, 10), sharex=True)

j, k = 0, 0
for i, ft in enumerate([i.parent._name for i in FB._feat_list]):
    if k > 3:
        j += 1
        k  = 0
    sns.violinplot(x='Label', y=ft, data=feats, ax=ax[j, k])
    ax[j, k].set_ylabel(None)
    ax[j, k].set_title(ft)
    ax[j, k].set_xlabel(None)
    
    k += 1

for k in range(4):
    ax[-1, k].set_xticklabels(['NG', 'G'])

f.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### Predictive Power Score

# %%
import ppscore

# %%
df_predictors = ppscore.predictors(feats, 'Label', output='df')
plt.figure()
ax = sns.barplot(data=df_predictors, x="x", y="ppscore")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.tight_layout()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pps_matrix = ppscore.matrix(feats)

# %%
plt.figure(figsize=(15, 10))
sns.heatmap(pps_matrix, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)
plt.tight_layout()
# plt.savefig('PPScore_matrix.pdf')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import RobustScaler

# %%
pca = PCA(n_components=5)
x_pca = pca.fit_transform(RobustScaler().fit_transform(feats))
df_pca = pd.DataFrame(x_pca, columns=[f'PC {i+1}' for i in range(x_pca.shape[1])])
df_pca['Label'] = Y
df_pca.head(2)
# Out:
#        PC 1      PC 2      PC 3      PC 4      PC 5  Label
# 0 -1.711513  5.869291 -1.432711  2.230261 -2.287106      1
# 1 -1.741723  5.418514 -0.500769  1.859952 -2.408586      1

# %%
sns.pairplot(df_pca, hue='Label')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from separation_stats import db_2class, corr_select, cohen_d, ttest_select, mwu_select, auc_score

# %%
sep_df = pd.DataFrame()
sep_df['Feature'] = feat_names

sep_df['DBI'], db_rank = db_2class(X_feat, Y)
sep_df['Correlation r'] = corr_select(X_feat, Y)
sep_df['T-test p'], sep_df['Cohens d'] = ttest_select(X_feat, Y)
sep_df['MWU-test p'], _ = mwu_select(X_feat, Y)
sep_df['AUC'] = auc_score(X_feat, Y)

sep_df['Cohens d'] = sep_df['Cohens d'].abs()
sep_df['AUC'] = sep_df['AUC'].apply(lambda i: 1 - i if i < 0.5 else i)

# %%
sep_df.sort_values('DBI')
# Out:
#                         Feature          DBI  Correlation r       T-test p  \
# 21             PowerSpectralSum     0.965947      -0.439613   0.000000e+00
# 20       DominantFrequencyValue     1.003710      -0.294097   0.000000e+00
# 23              SpectralEntropy     1.237202       0.412201   0.000000e+00
# 19            DominantFrequency     1.298202       0.087434  1.997463e-244
# 12           PermutationEntropy     1.497455      -0.434787   0.000000e+00
# 22             SpectralFlatness     1.678056       0.255478   0.000000e+00
# 17            DimensionlessJerk     2.057174      -0.334707   0.000000e+00
# 16                   JerkMetric     2.547032      -0.005624   3.205565e-02
# 6                           IQR     2.645830      -0.022779   3.844914e-18
# 1                 MeanCrossRate     2.646177      -0.335740   0.000000e+00
# 2                        StdDev     2.646476      -0.055497   1.864915e-99
# 7                           RMS     2.646476      -0.055497   1.864915e-99
# 13  ComplexityInvariantDistance     2.694615      -0.316375   0.000000e+00
# 5                         Range     2.875886      -0.050127   1.804724e-81
# 18                        SPARC     2.911317       0.036487   5.401799e-44
# 8               Autocorrelation     3.384121       0.316068   0.000000e+00
# 25             DetailPowerRatio     4.369635      -0.040789   1.521322e-54
# 15            RatioBeyondRSigma     4.685355      -0.212067   0.000000e+00
# 3                      Skewness     5.913675       0.090369  4.952060e-261
# 10                SignalEntropy     5.969245       0.001912   4.661265e-01
# 14         RangeCountPercentage     6.313728       0.215739   0.000000e+00
# 24                  DetailPower     9.542304      -0.131989   0.000000e+00
# 11                SampleEntropy    10.267897      -0.180574   0.000000e+00
# 0                          Mean    12.612764      -0.173941   0.000000e+00
# 4                      Kurtosis    29.001550      -0.064293  7.089651e-133
# 9                   LinearSlope  1598.826767       0.000239   9.272699e-01
#
#     Cohens d     MWU-test p       AUC
# 21  1.073380   0.000000e+00  0.783729
# 20  0.674816   0.000000e+00  0.710043
# 23  0.992193   0.000000e+00  0.793720
# 19  0.192486   0.000000e+00  0.574323
# 12  1.058831   0.000000e+00  0.794782
# 22  0.579510   0.000000e+00  0.689853
# 17  0.778961   0.000000e+00  0.675344
# 16  0.012335   0.000000e+00  0.675344
# 6   0.049970   0.000000e+00  0.664672
# 1   0.781670   0.000000e+00  0.708788
# 2   0.121896   0.000000e+00  0.655383
# 7   0.121896   0.000000e+00  0.655383
# 13  0.731397   0.000000e+00  0.709979
# 5   0.110070   0.000000e+00  0.647671
# 18  0.080072   0.000000e+00  0.642265
# 8   0.730610   0.000000e+00  0.710173
# 25  0.089527   0.000000e+00  0.671803
# 15  0.475899   0.000000e+00  0.618517
# 3   0.198999   0.000000e+00  0.575328
# 10  0.004193  3.837946e-169  0.546046
# 14  0.484539   0.000000e+00  0.629582
# 24  0.292014   0.000000e+00  0.656794
# 11  0.402629   0.000000e+00  0.595854
# 0   0.387367   0.000000e+00  0.597489
# 4   0.141290   0.000000e+00  0.569151
# 9   0.000525   1.708848e-02  0.503961

# %%
sep_df.sort_values('Cohens d', ascending=False)
# Out:
#                         Feature          DBI  Correlation r       T-test p  \
# 21             PowerSpectralSum     0.965947      -0.439613   0.000000e+00
# 12           PermutationEntropy     1.497455      -0.434787   0.000000e+00
# 23              SpectralEntropy     1.237202       0.412201   0.000000e+00
# 1                 MeanCrossRate     2.646177      -0.335740   0.000000e+00
# 17            DimensionlessJerk     2.057174      -0.334707   0.000000e+00
# 13  ComplexityInvariantDistance     2.694615      -0.316375   0.000000e+00
# 8               Autocorrelation     3.384121       0.316068   0.000000e+00
# 20       DominantFrequencyValue     1.003710      -0.294097   0.000000e+00
# 22             SpectralFlatness     1.678056       0.255478   0.000000e+00
# 14         RangeCountPercentage     6.313728       0.215739   0.000000e+00
# 15            RatioBeyondRSigma     4.685355      -0.212067   0.000000e+00
# 11                SampleEntropy    10.267897      -0.180574   0.000000e+00
# 0                          Mean    12.612764      -0.173941   0.000000e+00
# 24                  DetailPower     9.542304      -0.131989   0.000000e+00
# 3                      Skewness     5.913675       0.090369  4.952060e-261
# 19            DominantFrequency     1.298202       0.087434  1.997463e-244
# 4                      Kurtosis    29.001550      -0.064293  7.089651e-133
# 7                           RMS     2.646476      -0.055497   1.864915e-99
# 2                        StdDev     2.646476      -0.055497   1.864915e-99
# 5                         Range     2.875886      -0.050127   1.804724e-81
# 25             DetailPowerRatio     4.369635      -0.040789   1.521322e-54
# 18                        SPARC     2.911317       0.036487   5.401799e-44
# 6                           IQR     2.645830      -0.022779   3.844914e-18
# 16                   JerkMetric     2.547032      -0.005624   3.205565e-02
# 10                SignalEntropy     5.969245       0.001912   4.661265e-01
# 9                   LinearSlope  1598.826767       0.000239   9.272699e-01
#
#     Cohens d     MWU-test p       AUC
# 21  1.073380   0.000000e+00  0.783729
# 12  1.058831   0.000000e+00  0.794782
# 23  0.992193   0.000000e+00  0.793720
# 1   0.781670   0.000000e+00  0.708788
# 17  0.778961   0.000000e+00  0.675344
# 13  0.731397   0.000000e+00  0.709979
# 8   0.730610   0.000000e+00  0.710173
# 20  0.674816   0.000000e+00  0.710043
# 22  0.579510   0.000000e+00  0.689853
# 14  0.484539   0.000000e+00  0.629582
# 15  0.475899   0.000000e+00  0.618517
# 11  0.402629   0.000000e+00  0.595854
# 0   0.387367   0.000000e+00  0.597489
# 24  0.292014   0.000000e+00  0.656794
# 3   0.198999   0.000000e+00  0.575328
# 19  0.192486   0.000000e+00  0.574323
# 4   0.141290   0.000000e+00  0.569151
# 7   0.121896   0.000000e+00  0.655383
# 2   0.121896   0.000000e+00  0.655383
# 5   0.110070   0.000000e+00  0.647671
# 25  0.089527   0.000000e+00  0.671803
# 18  0.080072   0.000000e+00  0.642265
# 6   0.049970   0.000000e+00  0.664672
# 16  0.012335   0.000000e+00  0.675344
# 10  0.004193  3.837946e-169  0.546046
# 9   0.000525   1.708848e-02  0.503961

# %%
sep_df.sort_values('AUC', ascending=False)
# Out:
#                         Feature          DBI  Correlation r       T-test p  \
# 12           PermutationEntropy     1.497455      -0.434787   0.000000e+00
# 23              SpectralEntropy     1.237202       0.412201   0.000000e+00
# 21             PowerSpectralSum     0.965947      -0.439613   0.000000e+00
# 8               Autocorrelation     3.384121       0.316068   0.000000e+00
# 20       DominantFrequencyValue     1.003710      -0.294097   0.000000e+00
# 13  ComplexityInvariantDistance     2.694615      -0.316375   0.000000e+00
# 1                 MeanCrossRate     2.646177      -0.335740   0.000000e+00
# 22             SpectralFlatness     1.678056       0.255478   0.000000e+00
# 16                   JerkMetric     2.547032      -0.005624   3.205565e-02
# 17            DimensionlessJerk     2.057174      -0.334707   0.000000e+00
# 25             DetailPowerRatio     4.369635      -0.040789   1.521322e-54
# 6                           IQR     2.645830      -0.022779   3.844914e-18
# 24                  DetailPower     9.542304      -0.131989   0.000000e+00
# 7                           RMS     2.646476      -0.055497   1.864915e-99
# 2                        StdDev     2.646476      -0.055497   1.864915e-99
# 5                         Range     2.875886      -0.050127   1.804724e-81
# 18                        SPARC     2.911317       0.036487   5.401799e-44
# 14         RangeCountPercentage     6.313728       0.215739   0.000000e+00
# 15            RatioBeyondRSigma     4.685355      -0.212067   0.000000e+00
# 0                          Mean    12.612764      -0.173941   0.000000e+00
# 11                SampleEntropy    10.267897      -0.180574   0.000000e+00
# 3                      Skewness     5.913675       0.090369  4.952060e-261
# 19            DominantFrequency     1.298202       0.087434  1.997463e-244
# 4                      Kurtosis    29.001550      -0.064293  7.089651e-133
# 10                SignalEntropy     5.969245       0.001912   4.661265e-01
# 9                   LinearSlope  1598.826767       0.000239   9.272699e-01
#
#     Cohens d     MWU-test p       AUC
# 12  1.058831   0.000000e+00  0.794782
# 23  0.992193   0.000000e+00  0.793720
# 21  1.073380   0.000000e+00  0.783729
# 8   0.730610   0.000000e+00  0.710173
# 20  0.674816   0.000000e+00  0.710043
# 13  0.731397   0.000000e+00  0.709979
# 1   0.781670   0.000000e+00  0.708788
# 22  0.579510   0.000000e+00  0.689853
# 16  0.012335   0.000000e+00  0.675344
# 17  0.778961   0.000000e+00  0.675344
# 25  0.089527   0.000000e+00  0.671803
# 6   0.049970   0.000000e+00  0.664672
# 24  0.292014   0.000000e+00  0.656794
# 7   0.121896   0.000000e+00  0.655383
# 2   0.121896   0.000000e+00  0.655383
# 5   0.110070   0.000000e+00  0.647671
# 18  0.080072   0.000000e+00  0.642265
# 14  0.484539   0.000000e+00  0.629582
# 15  0.475899   0.000000e+00  0.618517
# 0   0.387367   0.000000e+00  0.597489
# 11  0.402629   0.000000e+00  0.595854
# 3   0.198999   0.000000e+00  0.575328
# 19  0.192486   0.000000e+00  0.574323
# 4   0.141290   0.000000e+00  0.569151
# 10  0.004193  3.837946e-169  0.546046
# 9   0.000525   1.708848e-02  0.503961

# %% [markdown]
# ### Pair plots (Top Features)

# %%
top_feats = ['PowerSpectralSum', 'PermutationEntropy', 'SpectralEntropy', 'DominantFrequency', 'DimensionlessJerk', 'MeanCrossRate']

sns.pairplot(feats, hue='Label', vars=top_feats)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
